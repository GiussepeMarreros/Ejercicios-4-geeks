# %%
import numpy as np
import random

# %%
palomar = [0]*days

# %%
def recurrencia(punketos, days):
  palomar = [0]*days
  for _ in range(punketos):
    birth_day = random.randint(0,days-1)
    palomar[birth_day] += 1
  return max(palomar) >= 2

# %%
match(35,360)
# Out:
# False

# %%
def probabilidad(days,punketos,trial):
  acum = 0
  for _ in range(trial):
    if recurrencia(days,punketos):
      acum += 1
  return acum/trial

# %%
probabilidad(360,25,100000)
# Out:
# 1.0

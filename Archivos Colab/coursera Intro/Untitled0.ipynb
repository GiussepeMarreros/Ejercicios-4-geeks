# %%
masa = 80
estatura = 1.8

def imc(masa, estatura):
   # desde aquí hacia abajo debes modificar el programa
  # modifica la variable imc
  # recuerda que los datos están en las variables masa y estatura
   return masa/(estatura**2)

# %%
print (imc)
# Out:
# <function imc at 0x789ebc5ee4d0>

# %%
def imc(masa, estatura):
    # Calcular el IMC con la fórmula masa / (estatura^2)
    return masa / (estatura ** 2)

# %%
print(imc)
# Out:
# <function imc at 0x789ebc5ede10>

# %%
distancia= 100
tiempo = 20

# %%
def velocidad(distancia, tiempo):
  resultado = "La velocidad es"+ str(distancia/tiempo)+"Km/h o"+str((((distancia*1000)/tiempo)/60)/60)+"m/s"
  # desde aquí hacia abajo debes modificar el programa
  # modifica la variable resultado
  # recuerda que los datos están en las variables distancia y tiempo
  return resultado

# %%
print(velocidad)
# Out:
# <function velocidad at 0x789ebc4bd990>

# %%
resultado = f"La velocidad es {distancia/tiempo:.2f}  Km/h o {(((distancia*1000)/tiempo)/60)/60:.2f} +  m/s"

# %%
print(resultado)
# Out:
# La velocidad es 5.00  Km/h o 1.39 +  m/s

# %%
resultado = f"La velocidad es {distancia / tiempo:.2f} Km/h o {((distancia * 1000) / tiempo) / 60 / 60:.2f} m/s"

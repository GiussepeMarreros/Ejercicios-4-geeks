# %%
import pandas as pd
import numpy as np
from scipy.stats import norm
import matplotlib.pyplot as plt

# %%
url = "https://raw.githubusercontent.com/it-ces/Datasets/refs/heads/main/icfesSaber11_20202.csv"
df = pd.read_csv(url)

# %%
df = df[df['COLE_DEPTO_UBICACION']=='BOGOTÁ'].copy()

# %%
mean = df['PUNT_MATEMATICAS'].mean()
std = df['PUNT_MATEMATICAS'].std() #sigma
norm.interval(0.95,loc=mean,scale= std/((df['PUNT_MATEMATICAS'].shape[0])**0.5))
# Out:
# (54.83436090275176, 54.986593313613675)

# %%
plt.hist(df['PUNT_MATEMATICAS'],bins=100)
# Out:
# (array([2.400e+01, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 2.000e+00,
#         7.000e+00, 7.000e+00, 1.700e+01, 1.900e+01, 2.000e+01, 3.500e+01,
#         5.000e+01, 7.100e+01, 8.400e+01, 1.110e+02, 1.140e+02, 1.620e+02,
#         2.150e+02, 2.630e+02, 3.180e+02, 3.880e+02, 4.590e+02, 5.400e+02,
#         6.390e+02, 7.440e+02, 8.890e+02, 1.047e+03, 1.080e+03, 1.229e+03,
#         1.389e+03, 1.528e+03, 1.641e+03, 1.693e+03, 1.907e+03, 2.042e+03,
#         2.130e+03, 2.251e+03, 2.434e+03, 2.547e+03, 2.586e+03, 2.742e+03,
#         2.717e+03, 2.881e+03, 2.842e+03, 2.937e+03, 2.879e+03, 2.734e+03,
#         2.642e+03, 2.661e+03, 2.424e+03, 2.303e+03, 2.158e+03, 1.925e+03,
#         1.767e+03, 1.592e+03, 1.480e+03, 1.241e+03, 1.132e+03, 9.740e+02,
#         8.930e+02, 6.800e+02, 6.000e+02, 4.090e+02, 3.620e+02, 3.010e+02,
# ...

# %%
# demostrar que

# %% [markdown]
# $$ \hat{N} = \frac{k_{1} * k_{2}}{recapture} $$
#
# $$ \mathbb{E}[ \hat{N}] = N $$

# %%
import numpy as np
N = 130

# %%
data = [i for i in range(1, N+1)]

# %%
k1 = 40
k2 = 40
book1  = np.random.choice(data, size=k1, replace=False)
book2 = np.random.choice(data, size=k2, replace=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-0d8b32d0479a> in <cell line: 3>()
#       1 k1 = 40
#       2 k2 = 40
# ----> 3 book1  = np.random.choice(data, size=k1, replace=False)
#       4 book2 = np.random.choice(data, size=k2, replace=False)
#
# NameError: name 'np' is not defined

# %%
book1

# %%
book2

# %%
acum = 0
for elemento in book1:
  if elemento in book2:
    acum = acum +1
recapts = acum

# %%
N_hat = (k1*k2)/recapts
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-df80b7a123e3> in <cell line: 1>()
# ----> 1 N_hat = (k1*k2)/recapts
#
# NameError: name 'recapts' is not defined

# %%
N_hat, N

# %%
def N_hat(k1,k2, N):
  data = [i for i in range(1, N+1)]
  book1  = np.random.choice(data, size=k1, replace=False)
  book2 = np.random.choice(data, size=k2, replace=False)
  acum = 0
  for elemento in book1:
    if elemento in book2:
      acum = acum +1
  recapts = acum
  return (k1*k2)/recapts

# %%
trials = 10000
outcomes = [N_hat(85, 90, 245) for _ in range(trials)]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-79aebcb3f2db> in <cell line: 2>()
#       1 trials = 10000
# ----> 2 outcomes = [N_hat(85, 90, 245) for _ in range(trials)]
#
# <ipython-input-3-79aebcb3f2db> in <listcomp>(.0)
#       1 trials = 10000
# ----> 2 outcomes = [N_hat(85, 90, 245) for _ in range(trials)]
#
# <ipython-input-2-0f3c7e696333> in N_hat(k1, k2, N)
#       1 def N_hat(k1,k2, N):
#       2   data = [i for i in range(1, N+1)]
# ----> 3   book1  = np.random.choice(data, size=k1, replace=False)
#       4   book2 = np.random.choice(data, size=k2, replace=False)
#       5   acum = 0
#
# NameError: name 'np' is not defined

# %%
import matplotlib.pyplot as plt

# %%
sum(outcomes)/len(outcomes)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-862f15a867e7> in <cell line: 1>()
# ----> 1 sum(outcomes)/len(outcomes)
#
# NameError: name 'outcomes' is not defined

# %%
plt.hist(outcomes)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-10f51c95c2f7> in <cell line: 1>()
# ----> 1 plt.hist(outcomes)
#
# NameError: name 'outcomes' is not defined

# %%
#Lanzar una Moneda 100 veces
#calcular la posibilidad de que caiga cara

import numpy as np
import random

moneda = [0,1]
cara = 1
cruz = 0
trials =100
resultado = []

def simulacion(trials):
  for i in range(trials):
    lanzamiento = np.random.randint(0,2)
    if lanzamiento == cara :
      resultado.append(1)
    else:
      resultado.append(0)

  return sum(resultado)/100

# %%
simulacion(100)
# Out:
# 0.53

# %%
from scipy.stats import binom

# %%
binom.pmf(50,100,0.5)
# Out:
# 0.07958923738717875

# %%
prob_acumulada = binom.pmf(1, 1, 0.5)
prob_acumulada
# Out:
# 0.5

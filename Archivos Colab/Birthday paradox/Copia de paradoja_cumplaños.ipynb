# %%
import numpy as np

personas=5
y=personas-1
f=[]
# 1 -(365!/365^personas)
#factorial
#x=5
#y=x-1 #=4
#f=[]

#for i in range(x):
#  f.append((x-y))
#  y-=1
#print(f)
#print(np.prod(f))

for i in range(personas):
  f.append(365-y)
  y-=1

print(f)
casos_no_favorable = np.divide(f,365)
#print(factorial)
producto_casos_no_favorable = np.prod(casos_no_favorable)
print("resultado de casos favorables: ", np.prod(f))
print("Todos los posibles casos= ", 365**personas)
print("probabilidad de que no suceda: ",producto_casos_no_favorable)
prob_que_suceda = 1 - (producto_casos_no_favorable)
suma_prob = producto_casos_no_favorable + prob_que_suceda



if prob_que_suceda==1:
  print("100% probabilidad!!!")
elif prob_que_suceda>0:
  print("probabilidad de que suceda es: " , prob_que_suceda)
print("suma de probabilidades: ", suma_prob)
# Out:
# [361, 362, 363, 364, 365]
# resultado de casos favorables:  6302555018760
# Todos los posibles casos=  6478348728125
# probabilidad de que no suceda:  0.9728644263002065
# probabilidad de que suceda es:  0.02713557369979347
# suma de probabilidades:  1.0

# %%
def paradoja_cumplaños(personas):
  y=personas-1
  f=[]
  for i in range(personas):
    f.append(365-y)
    y-=1

  #print(f)
  casos_no_favorable = np.divide(f,365)
  #print(factorial)
  producto_casos_no_favorable = np.prod(casos_no_favorable)
  #print("resultado de casos favorables: ", np.prod(f))
  #print("Todos los posibles casos= ", 365**personas)
  #print("probabilidad de que no suceda: ",producto_casos_no_favorable)
  prob_que_suceda = 1 - (producto_casos_no_favorable)
  suma_prob = producto_casos_no_favorable + prob_que_suceda

  if prob_que_suceda==1:
    #print("100% probabilidad!!!")
    return(print("100% probabilidad!!!"))
  elif prob_que_suceda>0:
    return (print("proabilidad que suceda: ",prob_que_suceda))
      #print("probabilidad de que suceda es: " , prob_que_suceda)
      #print("suma de probabilidades: ", suma_prob)

paradoja_cumplaños(23)
# Out:
# proabilidad que suceda:  0.5072972343239853

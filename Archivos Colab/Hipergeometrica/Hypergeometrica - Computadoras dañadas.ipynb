# %%
#probabilidad de obtener 8 computadores dañados en  una
#muestra de 12, un total de 25 computadoras y dentro del total hay 13 dañadas

import numpy as np
import scipy.stats as stats

M = 25
k= 8
N = 13
n = 12


probabilidad= stats.hypergeom.pmf(k, M, n, N, loc = 0)
probabilidad
# Out:
# 0.1225054323789012

# %%
#freud ilustration - problema de la carta que pierde el cartero (es roja o es azul?)
#se utiliza la Hipergeometrica (formula)
#es mas probable que salgan 2 cartas rojas cuando en el
#grupo (4) 3 son rojas, que cuando 2 son rojas

M = 4
k= 2
N = 3
n = 3


probabilidad1= stats.hypergeom.pmf(k, M, n, N, loc = 0)
probabilidad1
# Out:
# 0.75

# %%
M = 4
k= 2
N = 2
n = 3


probabilidad2= stats.hypergeom.pmf(k, M, n, N, loc = 0)
probabilidad2
# Out:
# 0.5

# %%
def hiper(M,n,N,k):
  return((combinatoria(n,k))*(m-n,N-k))/combinatoria(m,n)

print(hiper(M,n,N,k))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-381c2350791c> in <cell line: 4>()
#       2   return((combinatoria(n,k))*(m-n,N-k))/combinatoria(m,n)
#       3
# ----> 4 print(hiper(M,n,N,k))
#
# <ipython-input-19-381c2350791c> in hiper(M, n, N, k)
#       1 def hiper(M,n,N,k):
# ----> 2   return((combinatoria(n,k))*(m-n,N-k))/combinatoria(m,n)
#       3
#       4 print(hiper(M,n,N,k))
#
# NameError: name 'combinatoria' is not defined

# %%
def factorial(n)

# %%
import numpy  as np

# %%
mu = 100
sigma = 8.31
data = np.random.normal(mu, sigma, 10123)

# %%
sum(data)/len(data)
# Out:
# 100.1531564681691

# %%
sigma = np.array(data).std()

# %%
trials = 50000
size_sample = 40
means = []
for _ in range(trials):
  means.append(np.random.choice(data, size_sample).mean())

# %%
means = np.array(means)

# %%
means.mean()
# Out:
# 100.15583793691968

# %%
means.std(ddof=1)
# Out:
# 1.320677893131412

# %%
sigma/(size_sample**0.5)
# Out:
# 1.3139792653632687

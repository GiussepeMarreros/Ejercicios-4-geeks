# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random

# %%
x = []
y = []
rain = 1000
for _ in range(rain):
  x.append(random.uniform(-1,1))
  y.append(random.uniform(-1,1))

# %%
plt.scatter(x,y)

# %%
rain = 1000

x,y = (-1)

for x,y in range
  if x**2 + y**2 <= 1
  acum=acum + 1
  return (acum/rain )
# Out:
#   File "<ipython-input-4-a92d0484d337>", line 5
#     for x,y in range
#                     ^
# SyntaxError: expected ':'

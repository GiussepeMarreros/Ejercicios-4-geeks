# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
pibs = pd.read_excel("pibs-dptos.xlsx",
                     sheet_name='Cuadro 2',
                     skiprows=9,
                     usecols='A:T',
                     nrows=34)

# %%
pibs = pibs[pibs['DEPARTAMENTOS']!='COLOMBIA']

# %%
pibs.rename(columns = {'2020p':2020, '2021p':2021, '2022pr':2022}, inplace=True)

# %%
pibs.columns
# Out:
# Index(['Código Departamento (DIVIPOLA)',                  'DEPARTAMENTOS',
#                                    2005,                             2006,
#                                    2007,                             2008,
#                                    2009,                             2010,
#                                    2011,                             2012,
#                                    2013,                             2014,
#                                    2015,                             2016,
#                                    2017,                             2018,
#                                    2019,                             2020,
#                                    2021,                             2022],
#       dtype='object')

# %%
data
# Out:
#     time    inequality       ratio
# 0   2005  26519.614037  984.470277
# 1   2006  28351.348915  982.475029
# 2   2007  30264.394022  909.206664
# 3   2008  31158.465753  889.646627
# 4   2009  31559.587031  877.495590
# 5   2010  32658.132318  879.183821
# 6   2011  34664.741849  878.465335
# 7   2012  35921.222578  909.428222
# 8   2013  37371.554489  876.527632
# 9   2014  39317.650655  885.404712
# 10  2015  40767.152499  884.496932
# 11  2016  41703.201640  894.039072
# 12  2017  42465.529429  895.996743
# 13  2018  43895.296696  893.332444
# 14  2019  45422.555588  892.871089
# 15  2020  42408.303564  884.511735
# 16  2021  47374.025773  892.671173
# 17  2022  51602.153450  957.357884

# %%
sts, ratio = [], []
for year in range(2005, 2023):
  sts.append(pibs[year].std())
  ratio.append(pibs[year].max()/pibs[year].min()) # ratio

# %%
plt.plot(range(2005, 2023), sts)

# %%
data = pd.DataFrame({'time':range(2005,2023),
                     'inequality':sts,
                     'ratio':ratio} )

# %%
plt.plot(data['time'], data['ratio'])

# %%
import pandas as pd 
import numpy as np
import re

# %%
df = pd.read_excel('df1-track-base-de-datos.xlsx')
df
# Out:
#            var1 var2    var3         var4  var5         var6
# 0            10    0    rojo           19     1          Nan
# 1            20    1    azul           22     2  No registra
# 2           333    1    azul           33     3          NAN
# 3            12    1  blanco            @     1          NAN
# 4            34    1  blanco  No registra     2       Acepta
# 5            12  NaN    rojo           10     3       Acepta
# 6          1 12  NaN   verde           22     1       ACEPTA
# 7            12    0    azul           33     2       ACEPTA
# 8           123    1   azul1           11     3          NaN
# 9            10    1   azul4           33     1      no dato
# 10           2o    1    azul           44     2          Nan
# 11           23    o    azul           12     3       ACEPTA
# 12          NaN    0       0           12     1    NO ACEPTA
# 13          Nan    1    azul           33     2    NO ACEPTA
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   var1    18 non-null     object
#  1   var2    17 non-null     object
#  2   var3    19 non-null     object
#  3   var4    19 non-null     object
#  4   var5    19 non-null     int64
#  5   var6    18 non-null     object
# dtypes: int64(1), object(5)
# memory usage: 1.0+ KB

# %%
strings=[]
for column in df.columns:
    if df[column].dtype.name == object:
        strings.append(column)

print(strings)
# Out:
# []

# %%
def std_str(strings):
    if isinstance(string)==str:
        string=string.upper()
        string=string.replace('Á','A')
        return string
    else:
        return string

# %%
df['var3']= df['var3'].apply(lambda x: std_str(str(x)))
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[73], line 1
# ----> 1 df['var3']= df['var3'].apply(lambda x: std_str(str(x)))
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/series.py:4924, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)
#    4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)
#    4915     dtype: float64
#    4916     """
#    4917     return SeriesApply(
#    4918         self,
#    4919         func,
#    4920         convert_dtype=convert_dtype,
#    4921         by_row=by_row,
#    4922         args=args,
#    4923         kwargs=kwargs,
# -> 4924     ).apply()
#
# ...

# %%
def isnum (string):
    return bool(re.match(r'^\d+(\.\d+)?$', string))

def bynary(string):
    return bool(re.match(r'^[0-1]+(\.0+)?$', string))

# %%
def num_percent(df,col):
    return df[col].apply(lambda x: isnum(str(x))).sum()/df[col].apply(lambda x:pd.notna(x)).sum()

def is_bynary(df,col):
    return df[col].apply(lambda x: bynary(str(x))).sum()/df[col].apply(lambda x:pd.notna(x)).sum()

# %%
# Out:
# 0              19
# 1              22
# 2              33
# 3               @
# 4     No registra
# 5              10
# 6              22
# 7              33
# 8              11
# 9              33
# 10             44
# 11             12
# 12             12
# 13             33
# 14             23
# 15            132
# 16             33
# 17             12
# 18              1
# Name: var4, dtype: object

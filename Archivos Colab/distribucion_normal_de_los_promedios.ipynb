# %%
import numpy as np
import matplotlib.pyplot as ptl
import random

datos = [35,40,56,25,30,14,29, 1,3,47,98,25,99,640,8566,12,35,334,111,1,65,89,77,777,9842,5,40,56,25,30,14,29, 1,3,47,98,25,99,6,856,12,35,334,11,1,65,8,77,777,982,11,1,65,89,77,777,9842,5,40,56,25,30,14,29, 1,3,47,98,25,99,6,856,111,1,65,89,77,777,9842,5,40,56,25,30,14,29, 1,3,47,98,25,99,6,856,1]

# %%
np.array(datos).mean()
# Out:
# 517.6842105263158

# %%
medias = []
trials = 3000000
for i in range(trials):
  muestra = np.random.choice(datos,35)
  promedio = np.array(muestra).mean()
  medias.append(promedio)

# %%
ptl.hist(medias)
# Out:
# (array([6.674550e+05, 1.022855e+06, 7.649100e+05, 3.690600e+05,
#         1.304830e+05, 3.558200e+04, 7.920000e+03, 1.465000e+03,
#         2.430000e+02, 2.700000e+01]),
#  array([  18.08571429,  280.85428571,  543.62285714,  806.39142857,
#         1069.16      , 1331.92857143, 1594.69714286, 1857.46571429,
#         2120.23428571, 2383.00285714, 2645.77142857]),
#  <BarContainer object of 10 artists>)
